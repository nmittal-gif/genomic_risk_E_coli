# %%
# !pwd
# Out:
# /Users/neha/iResearch_Genomic_Risk/Pipeline_bash

# %%
# !bash /Users/neha/iResearch_Genomic_Risk/Pipeline_bash/script/run_genomic_risk_pipeline.sh
# Out:
# ...
#  GENOMIC RISK ANALYSIS PIPELINE START
# ...
# Step 0: Downloading Reference Genomes...
# Total accessions: 465
# Already downloaded: 465
# Remaining: 0
#
# Download finished
# Total time: 0 minutes 0 seconds
# Step 1: Metadata Processing...
# Running Metadata Analysis...
# Successfully created/verified metadata_analysis directory at: /Users/neha/iResearch_Genomic_Risk/Pipeline_bash/Results/metadata_analysis
# ===== METADATA ANALYSIS STARTED =====
# The metadata file is:
#           accession  tax_id  ... host_clean      diversity_group
# 0  GCF_033725995.1     562  ...      human   USA_human_10/18/23
# 1  GCA_022558405.1     562  ...      human  China_human_8/14/18
# 2  GCF_001455385.1     562  ...      human  China_human_9/15/07
# 3  GCF_052884205.1     562  ...      human     China_human_1999
# 4  GCF_027925785.1     562  ...      human     Japan_human_2008
#
# [5 rows x 15 columns]
# The columns in the metadata file are:
# ...
